# %%
import random
def main():
    inputString = input("Enter a string: ")
    if len(inputString) >= 4:
        random_indices = random.sample(range(len(inputString)), 2)
        filtered = [c for i, c in enumerate(inputString) if i not in random_indices]
        r = ''.join(reversed(filtered))
        print("Reversed string:", r)
if __name__ == "__main__":
    main()
# Out:
# Enter a string: pythonnn
# Reversed string: nnnoyp

# %%
number1 = float(input("Enter the first number: "))
number2 = float(input("Enter the second number: "))

addition = number1 + number2
subtraction = number1 - number2
multiplication = number1 * number2
# making sure it is not zero here, in avoiding undefined
if number2 != 0:
    division = number1 / number2
print(f"Addition: {addition}")
print(f"Subtraction: {subtraction}")
print(f"Multiplication: {multiplication}")
print(f"Division: {division}")
# Out:
# Enter the first number: 4
# Enter the second number: 2
# Addition: 6.0
# Subtraction: 2.0
# Multiplication: 8.0
# Division: 2.0

# %%
inputString = input("Enter the input: ")
modifiedString = inputString.replace('python', 'pythons')
print(modifiedString)
# Out:
# Enter the input: welcome to python class
# welcome to pythons class

# %%
inputScore = float(input("Enter the class score: "))
# Given Grading on some estimation, as i dont remember exactly
TopScore = 85
ModerateScore = 70
AverageScore = 60
LowScore = 50

if inputScore >= TopScore:
    letter_grade = "A"
elif inputScore >= ModerateScore:
    letter_grade = "B"
elif inputScore >= AverageScore:
    letter_grade = "C"
elif inputScore >= LowScore:
    letter_grade = "D"
else:
    letter_grade = "F"

print("Student Grade", letter_grade)
# Out:
# Enter the class score: 75
# Student Grade B
